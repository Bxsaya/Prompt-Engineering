# %%
import openai
import os
from IPython.display import display, Markdown, HTML, Latex, JSON
from redlines import Redlines
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0): 
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message["content"]

# %%
reviews = [
"This product is absolutely amazing! It exceeded my expectations and has made a huge difference in my life."
"I'm not sure why anyone would buy this product. It's expensive and doesn't seem to work any better than cheaper alternatives."
"I was skeptical at first, but after using this product for a few weeks, I can say with confidence that it really does work."
"This product is a game-changer! It's so innovative and well-designed that it's hard to believe no one thought of it sooner."
"I'm really disappointed in this product. It didn't live up to the hype and I feel like I wasted my money."
"I love this product! It's helped me so much and I don't know how I ever lived without it."
"This product is okay, but it's not the best option out there. I think there are better alternatives on the market."
"I had high hopes for this product, but unfortunately, it didn't work for me. I wouldn't recommend it."
"This is the best product I've ever used! It's truly life-changing and I can't imagine going back to my old routine."
"I don't understand why anyone would buy this product. It's overpriced and doesn't deliver on its promises."
"I'm really impressed with this product. It's affordable, effective, and easy to use. I highly recommend it."
"I was hesitant to try this product, but I'm so glad I did! It's made a huge difference in my life and I can't imagine going back."
"This product is just okay. It's not bad, but it's not amazing either. I think there are better options out there."
"I'm so disappointed in this product. It didn't work at all and I feel like I wasted my money."
"I love this product! It's so effective and easy to use. I would recommend it to anyone."
"This product is a waste of money. It's expensive and doesn't deliver on its promises."
"I'm really happy with this product. It's made a big difference in my life and I would definitely recommend it to others."
"I was hesitant to buy this product, but I'm so glad I did. It's exceeded my expectations and has made a big difference in my daily routine."
"I don't think this product is worth the price. It's not bad, but it's not amazing either."
"I'm really impressed with this product. It's well-designed, effective, and affordable. I would definitely recommend it."

]

# %%
for i in range(len(reviews)):
    prompt = f"""
    Your task is to perform sentiment analysis for each review 

    The review is delimited with triple backticks. \
    Format your response as a JSON object with \
    "Review" and "Sentiment" as the keys for each review.
    Try and measure in percentage form how accurate the analysis is.\
    Include emotions e.g., happy, sad, angry etc, and how loyal they are to the brand
    If the information isn't present, use "unknown" \
    as the value. 

    Review: ```{reviews[i]}```
    """

    response = get_completion(prompt)
    print(i, response, "\n")
# Out:
# 0 {
#     "reviews": [
#         {
#             "Review": "This product is absolutely amazing! It exceeded my expectations and has made a huge difference in my life.",
#             "Sentiment": {
#                 "Emotion": "happy",
#                 "Loyalty": "loyal",
#                 "Accuracy": "90%"
#             }
#         },
#         {
#             "Review": "I'm not sure why anyone would buy this product. It's expensive and doesn't seem to work any better than cheaper alternatives.",
#             "Sentiment": {
#                 "Emotion": "angry",
#                 "Loyalty": "not loyal",
#                 "Accuracy": "80%"
#             }
#         },
#         {
#             "Review": "I was skeptical at first, but after using this product for a few weeks, I can say with confidence that it really does work.",
#             "Sentiment": {
#                 "Emotion": "happy",
#                 "Loyalty": "loyal",
#                 "Accuracy": "95%"
#             }
# ...

# %%
contract = f"""

FARMING CONTRACT FOR MARIJUANA CULTIVATION BETWEEN [FARMER NAME] AND [COMPANY NAME]\
This contract ("Contract") is made and entered into as of [DATE] (the "Effective Date") by and between [FARMER NAME] ("Farmer"), located at [FARMER ADDRESS], and [COMPANY NAME] ("Company"), located at [COMPANY ADDRESS].\
CULTIVATION OF MARIJUANA Farmer agrees to cultivate and harvest marijuana crops on [FARMER LAND] acres of land in [LOCATION] for the duration of the cultivation period, which will begin on [START DATE] and end on [END DATE].\
SPECIFICATIONS OF CULTIVATION The marijuana will be cultivated in accordance with the specifications provided by the Company, including but not limited to the following:\
The cultivation of marijuana will be done in accordance with Costa Rican law and any other applicable regulations.\
The marijuana will be grown using organic and sustainable farming practices.\
The marijuana will be grown without the use of pesticides, herbicides, or other harmful chemicals.\
The marijuana will be harvested and processed in accordance with the Company's guidelines.\
PAYMENT AND COMPENSATION Company agrees to pay Farmer [PAYMENT AMOUNT] per pound of marijuana harvested. Payment will be made within [PAYMENT TERM] days of the harvest.\
OWNERSHIP AND TITLE Title to the marijuana crops cultivated by Farmer pursuant to this Contract shall remain with the Company until the crops are harvested, at which point title shall pass to the Company.\
TERM AND TERMINATION This Contract shall commence on the Effective Date and shall continue until the completion of the cultivation period. Either party may terminate this Contract upon written notice to the other party if the other party breaches any material term or condition of this Contract.\
CONFIDENTIALITY Farmer agrees to keep confidential all information relating to the Company's business, including but not limited to the Company's trade secrets, proprietary information, and any other information not generally known to the public. Farmer shall not disclose such information to any third party without the prior written consent of the Company.\
GOVERNING LAW This Contract shall be governed by and construed in accordance with the laws of Costa Rica. Any dispute arising out of or in connection with this Contract, including any question regarding its existence, validity or termination, shall be referred to and finally resolved by arbitration in accordance with the rules of the Costa Rican Chamber of Commerce.\
IN WITNESS WHEREOF, the parties have executed this Contract as of the date first above written.\
[COMPANY NAME] By: _____________________________ Name: ___________________________ Title: ____________________________\
[FARMER NAME] By: _____________________________ Name: ___________________________ Title: ____________________________\

"""

# %%
prompt = f"""
The contract is delimited with triple backticks.
Translate the following contract to Swahili and write it in the original structure rather than just one long line.

Translate: ```{contract}```
"""
response = get_completion(prompt)
print(response)
# Out:
# ```
#
# ...

# %%
prompt = f"""

The farmers name is Giancarlo Esposito, the location is La Paz and the company is Ngeni Farms.

Identify the country mentioned in the contract. 

and autofill every text in [] as guided.

The contract is delimited with triple backticks. \
Format your response as a JSON object with \
"Farmer's name", "Location", "Country", "Company" and "Crop Cultivated" as the keys. 
If the information isn't present, use "unknown" \
as the value.

Autofill: ```{contract}```

"""
response = get_completion(prompt)
print(response)
# Out:
# ```json
# {
#   "Farmer's name": "Giancarlo Esposito",
#   "Location": "La Paz",
#   "Country": "Costa Rica",
#   "Company": "Ngeni Farms",
#   "Crop Cultivated": "marijuana"
# }
# ```
